# %%
import os
from glob import glob
import pandas as pd
import numpy as np
from sklearn import neighbors, preprocessing
from sklearn.model_selection import train_test_split

DATA_FOLDER_PATH = os.path.abspath("../../data")
TRAINING_DATASET = DATA_FOLDER_PATH + "/" + "open-hand"
df = pd.read_csv(TRAINING_DATASET + "/dataset.csv", index_col=False)

# %%
df.head()
# Out:
#          x1        y1        x2        y2        x3        y3        x4  \
# 0  0.150947  0.481667  0.186751  0.450175  0.206698  0.398153  0.224514
# 1  0.150565  0.480708  0.184690  0.441548  0.205700  0.392375  0.223914
# 2  0.150741  0.479601  0.184697  0.442668  0.206362  0.391535  0.224278
# 3  0.150801  0.477725  0.186186  0.439984  0.208041  0.390592  0.226621
# 4  0.150193  0.480138  0.186615  0.443922  0.208292  0.392527  0.226235
#
#          y4        x5        y5  ...       y17       x18       y18       x19  \
# 0  0.366040  0.245526  0.346371  ...  0.257696  0.094588  0.377607  0.076155
# 1  0.358123  0.243697  0.337025  ...  0.255542  0.096117  0.375972  0.077321
# 2  0.356658  0.244743  0.334848  ...  0.250279  0.094978  0.373154  0.076938
# 3  0.356438  0.245460  0.333675  ...  0.251843  0.096774  0.371606  0.077292
# 4  0.357923  0.245076  0.335195  ...  0.250601  0.096208  0.373462  0.076392
#
#         y19       x20       y20       x21       y21      class
# 0  0.351346  0.066976  0.333385  0.058266  0.313947  Open Hand
# 1  0.347563  0.063598  0.327615  0.052356  0.310100  Open Hand
# 2  0.344518  0.064624  0.323785  0.055416  0.305682  Open Hand
# 3  0.345116  0.063805  0.324311  0.052520  0.306287  Open Hand
# 4  0.344284  0.063653  0.323291  0.052849  0.305793  Open Hand
#
# [5 rows x 43 columns]

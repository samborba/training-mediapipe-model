# %%
import os
import pandas as pd

DATA_FOLDER_PATH = os.path.abspath("../../data")
TRAINING_DATASET = DATA_FOLDER_PATH + "/" + "open-hand"

TRAINING_DATASET
# Out:
# '/l/disk0/sborba/Downloads/training-mediapipe-model/data/open-hand'
